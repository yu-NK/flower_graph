# %%
# %matplotlib inline

import numpy as np
import cv2
from tqdm import tqdm
import matplotlib.pyplot as plt
import networkx as nx

height = 858
width  = 915
depth  = 888

def main():
    p_x = []
    p_y = []
    p_z = []
    
    img = cv2.imread('../../00_Input/flower_CT_photo/ORA/[vg-data] ORA/volume_1/ORA-{0:03d}.tif'.format(z),0)
    
    for z in tqdm(range(height)):
        for y in range(height):
            for x in range(height):
        

if __name__ == "__main__":
    main()

# %%
# %matplotlib inline

import numpy as np
import cv2
from tqdm import tqdm
import matplotlib.pyplot as plt
import networkx as nx
import sys

#height = 858
#width  = 915

img_num = 479
left = 230
right = 293

height = 59
width  = 63

#depth  = 888
diff = 15

def main():
    
    G = nx.Graph()
    pos = {}
    edge_weight = []
    
    temp = np.zeros((height,width),dtype = 'i4')
    cnt = 0
    
    #img = cv2.imread('../../flower_CT_photo/ORA/[vg-data] ORA/volume_1/ORA-{0:03d}.tif'.format(img_num),0)
    img = cv2.imread('ORA-{0:03d}_{1:d}-{2:d}.png'.format(img_num,left,right),0)
    
    for y in tqdm(range(height)):
        for x in range(width):
            if(img[y,x]>50):
                temp[y,x] = cnt
                G.add_node(cnt)
                pos[cnt]=(x,y)
                cnt += 1
            else:
                img[y,x]=0

    for y in tqdm(range(height)):
        for x in range(width):
            node1 = temp[y,x] 
            if(img[y,x]>0):
                brig1 = img[y,x]
                
                if(x!=(width-1)):
                        
                    if(img[y,x+1]>0):
                        brig2 = img[y,x+1]
                        diff_n = abs(int(brig1)-int(brig2))
                        node2 = temp[y,x+1]
                        if(diff_n < diff):
                            G.add_edge(node1,node2)
                            edge_weight.append(diff-diff_n+1)
                        
                if(y!=(height-1)):
                    
                    if(x!=0):
                        if(img[y+1,x-1]>0):
                            brig2 = img[y+1,x-1]
                            diff_n = abs(int(brig1)-int(brig2))
                            node2 = temp[y+1,x-1]
                            if(diff_n < diff):
                                G.add_edge(node1,node2)
                                edge_weight.append(diff-diff_n+1)
                            
                    if(img[y+1,x]>0):
                        brig2 = img[y+1,x]
                        diff_n = abs(int(brig1)-int(brig2))
                        node2 = temp[y+1,x]
                        if(diff_n < diff):
                            G.add_edge(node1,node2)
                            edge_weight.append(diff-diff_n+1)

                    if(x!=(width-1)):
                        if(img[y+1,x+1]>0):
                            brig2 = img[y+1,x+1]
                            diff_n = abs(int(brig1)-int(brig2))
                            node2 = temp[y+1,x+1]
                            if(diff_n < diff):
                                G.add_edge(node1,node2)
                                edge_weight.append(diff-diff_n+1)
    
    print(nx.info(G))
    
    
    #plt.figure(figsize=(20,19),dpi=100)
    fig,ax = plt.subplots(figsize=(20,19),dpi=100)
    ax.invert_yaxis()
    
    print('G_draw')
    #nx.draw(G,pos,node_size=10,width = edge_weight)
    nx.draw(G,pos,node_size=50)
    
    print('plt_draw')
    #plt.show()
    plt.savefig("ORA-{0:03d}_{1:d}-{2:d}_{3:d}_edge.pdf".format(img_num,left,right,diff))
    #plt.savefig("ORA-{0:03d}_{1:d}.pdf".format(img_num,diff))

if __name__ == "__main__":
    main()

# %%
# %matplotlib inline

import numpy as np
import cv2
from tqdm import tqdm
import matplotlib.pyplot as plt
import networkx as nx
import sys

img_num = 479
left = 230
right = 293

height = 59
width  = 63

#depth  = 888
diff = 15

def main():
    
    G = nx.Graph()
    pos = {}
    edge_weight = []
    
    temp = np.zeros((height,width),dtype = 'i4')
    cnt = 0
    
    #img = cv2.imread('../../flower_CT_photo/ORA/[vg-data] ORA/volume_1/ORA-{0:03d}.tif'.format(img_num),0)
    img = cv2.imread('ORA-{0:03d}_{1:d}-{2:d}.png'.format(img_num,left,right),0)
    
    for z in tqdm(range(477,482)):
        
        for y in range(height):
            for x in range(width):
                if(img[y,x]>50):
                    temp[y,x] = cnt
                    G.add_node(cnt)
                    pos[cnt]=(x,y)
                    cnt += 1
                else:
                    img[y,x]=0

                    
    for y in tqdm(range(height)):
        for x in range(width):
            node1 = temp[y,x] 
            if(img[y,x]>0):
                brig1 = img[y,x]
                
                if(x!=(width-1)):
                        
                    if(img[y,x+1]>0):
                        brig2 = img[y,x+1]
                        diff_n = abs(int(brig1)-int(brig2))
                        node2 = temp[y,x+1]
                        if(diff_n < diff):
                            G.add_edge(node1,node2)
                            edge_weight.append(diff-diff_n+1)
                        
                if(y!=(height-1)):
                    
                    if(x!=0):
                        if(img[y+1,x-1]>0):
                            brig2 = img[y+1,x-1]
                            diff_n = abs(int(brig1)-int(brig2))
                            node2 = temp[y+1,x-1]
                            if(diff_n < diff):
                                G.add_edge(node1,node2)
                                edge_weight.append(diff-diff_n+1)
                            
                    if(img[y+1,x]>0):
                        brig2 = img[y+1,x]
                        diff_n = abs(int(brig1)-int(brig2))
                        node2 = temp[y+1,x]
                        if(diff_n < diff):
                            G.add_edge(node1,node2)
                            edge_weight.append(diff-diff_n+1)

                    if(x!=(width-1)):
                        if(img[y+1,x+1]>0):
                            brig2 = img[y+1,x+1]
                            diff_n = abs(int(brig1)-int(brig2))
                            node2 = temp[y+1,x+1]
                            if(diff_n < diff):
                                G.add_edge(node1,node2)
                                edge_weight.append(diff-diff_n+1)
    
    print(nx.info(G))
    
    
    #plt.figure(figsize=(20,19),dpi=100)
    fig,ax = plt.subplots(figsize=(20,19),dpi=100)
    ax.invert_yaxis()
    
    print('G_draw')
    #nx.draw(G,pos,node_size=10,width = edge_weight)
    nx.draw(G,pos,node_size=50)
    
    print('plt_draw')
    #plt.show()
    plt.savefig("ORA-{0:03d}_{1:d}-{2:d}_{3:d}_edge.pdf".format(img_num,left,right,diff))
    #plt.savefig("ORA-{0:03d}_{1:d}.pdf".format(img_num,diff))

if __name__ == "__main__":
    main()

# %%
from PIL import Image

im = Image.open('../../flower_CT_photo/ORA/[vg-data] ORA/volume_1/ORA-477.tif')

im.crop((535,651,578,689)).save('Input/ORA-477_535-578.png')

# %%
#全ボクセルの隣接行列を表現　メモリエラー発生のため保留
# %matplotlib inline

import numpy as np
import cv2
from tqdm import tqdm
import matplotlib.pyplot as plt
import networkx as nx
import sys

height = 858
width  = 915
depth  = 888

diff = 15

def main():
    
    temp = np.zeros((depth,height,width),dtype = 'i4')
    A = np.zeros((73904285,73904285),dtype = 'i4')
    cnt = 0
    
    print('隣接行列作成中')
    for z in tqdm(depth):
        img = cv2.imread('../../flower_CT_photo/ORA/ORA60/ORA-{0:03d}_60.png'.format(z),0)
        for y in range(height):
            for x in range(width):
                if(img[y,x]>0):
                    temp[z,y,x] = cnt
                    cnt += 1
    
    for z in tqdm(range(depth)):
        img = cv2.imread('../../flower_CT_photo/ORA/ORA60/ORA-{0:03d}_60.png'.format(z),0)
        
        if(z != (depth-1)):
            img_a = cv2.imread('../../flower_CT_photo/ORA/ORA60/ORA-{0:03d}_60.png'.format(z),0)
        
        for y in range(height):
            for x in range(width):
                
                node1 = temp[z,y,x]
                
                if(img[y,x]>0):
                    brig1 = img[y,x]
                
                    if(x!=(width-1)):
                        
                        if(img[y,x+1]>0):
                            brig2 = img[y,x+1]
                            diff_n = abs(int(brig1)-int(brig2))
                            node2 = temp[z,y,x+1]
                            if(diff_n < diff):
                                A[node1,node2] = 1
                                A[node2,node1] = 1
                        
                    if(y!=(height-1)):
                    
                        if(x!=0):
                            if(img[y+1,x-1]>0):
                                brig2 = img[y+1,x-1]
                                diff_n = abs(int(brig1)-int(brig2))
                                node2 = temp[z,y+1,x-1]
                                if(diff_n < diff):
                                    A[node1,node2] = 1
                                    A[node2,node1] = 1
                            
                        if(img[y+1,x]>0):
                            brig2 = img[y+1,x]
                            diff_n = abs(int(brig1)-int(brig2))
                            node2 = temp[z,y+1,x]
                            if(diff_n < diff):
                                A[node1,node2] = 1
                                A[node2,node1] = 1

                        if(x!=(width-1)):
                            if(img[y+1,x+1]>0):
                                brig2 = img[y+1,x+1]
                                diff_n = abs(int(brig1)-int(brig2))
                                node2 = temp[z,y+1,x+1]
                                if(diff_n < diff):
                                    A[node1,node2] = 1
                                    A[node2,node1] = 1
                                    
                    if(z!=(depth-1)):
                        if(img_a[y,x]>0):
                            brig2 = img_a[y,x]
                            diff_n = abs(int(brig1)-int(brig2))
                            node2 = temp[z+1,y,x]
                            if(diff_n < diff):
                                A[node1,node2] = 1
                                A[node2,node1] = 1
                                
                        if(x!=0):
                            if(img_a[y,x-1]>0):
                                brig2 = img_a[y,x-1]
                                diff_n = abs(int(brig1)-int(brig2))
                                node2 = temp[z+1,y,x-1]
                                if(diff_n < diff):
                                    A[node1,node2] = 1
                                    A[node2,node1] = 1
                                    
                        if(x!=(width-1)):
                            if(img_a[y,x+1]>0):
                                brig2 = img_a[y,x+1]
                                diff_n = abs(int(brig1)-int(brig2))
                                node2 = temp[z+1,y,x+1]
                                if(diff_n < diff):
                                    A[node1,node2] = 1
                                    A[node2,node1] = 1
                                
                        if(y!=0):
                            if(img_a[y-1,x]>0):
                                brig2 = img_a[y-1,x-1]
                                diff_n = abs(int(brig1)-int(brig2))
                                node2 = temp[z+1,y-1,x-1]
                                if(diff_n < diff):
                                    A[node1,node2] = 1
                                    A[node2,node1] = 1
                            
                            if(x!=0):
                                if(img_a[y-1,x-1]>0):
                                    brig2 = img_a[y-1,x]
                                    diff_n = abs(int(brig1)-int(brig2))
                                    node2 = temp[z+1,y-1,x]
                                    if(diff_n < diff):
                                        A[node1,node2] = 1
                                        A[node2,node1] = 1
                                        
                            if(x!=(width-1)):
                                if(img_a[y-1,x+1]>0):
                                    brig2 = img_a[y-1,x]
                                    diff_n = abs(int(brig1)-int(brig2))
                                    node2 = temp[z+1,y-1,x]
                                    if(diff_n < diff):
                                        A[node1,node2] = 1
                                        A[node2,node1] = 1
                                    
                        if(y!=(height-1)):
                            if(img_a[y+1,x]>0):
                                brig2 = img_a[y+1,x-1]
                                diff_n = abs(int(brig1)-int(brig2))
                                node2 = temp[z+1,y+1,x-1]
                                if(diff_n < diff):
                                    A[node1,node2] = 1
                                    A[node2,node1] = 1
                            
                            if(x!=0):
                                if(img_a[y+1,x-1]>0):
                                    brig2 = img_a[y+1,x-1]
                                    diff_n = abs(int(brig1)-int(brig2))
                                    node2 = temp[z+1,y+1,x-1]
                                    if(diff_n < diff):
                                        A[node1,node2] = 1
                                        A[node2,node1] = 1
                                        
                            if(x!=(width-1)):
                                if(img_a[y+1,x+1]>0):
                                    brig2 = img_a[y+1,x+1]
                                    diff_n = abs(int(brig1)-int(brig2))
                                    node2 = temp[z+1,y+1,x+1]
                                    if(diff_n < diff):
                                        A[node1,node2] = 1
                                        A[node2,node1] = 1
    
    
    #plt.figure(figsize=(20,19),dpi=100)
    #fig,ax = plt.subplots(figsize=(20,19),dpi=100)
    #ax.invert_yaxis()
    
    #print('G_draw')
    #nx.draw(G,pos,node_size=10,width = edge_weight)
    #nx.draw(G,pos,node_size=50)
    
    #print('plt_draw')
    #plt.show()
    #plt.savefig("ORA-{0:03d}_{1:d}-{2:d}_{3:d}_edge.pdf".format(img_num,left,right,diff))
    #plt.savefig("ORA-{0:03d}_{1:d}.pdf".format(img_num,diff))

if __name__ == "__main__":
    main()

# %%
import cv2
from tqdm import tqdm

height = 858
width  = 915
depth  = 888

cnt = 0

for z in tqdm(range(888)):
    img = cv2.imread('../../flower_CT_photo/ORA/[vg-data] ORA/volume_1/ORA-{0:03d}.tif'.format(z),0)
    
    for y in range(height):
        for x in range(width):
            if(img[y,x]>=60):
                cnt += 1
            else:
                img[y,x]=0
    
    #cv2.imwrite('../../flower_CT_photo/ORA/ORA60/ORA-{0:03d}_60.png'.format(z),img)

print(cnt)

# %%
import cv2
from tqdm import tqdm

height = 858
width  = 915
depth  = 888

cnt = 0

for z in tqdm(range(500,503)):
    img = cv2.imread('../../flower_CT_photo/ORA/[vg-data] ORA/volume_1/ORA-{0:03d}.tif'.format(z),0)
    
    binary = cv2.inRange(img, 60, 255)
    
    
    cnt = cnt + cv2.countNonZero(binary)

print(cnt)

# %%
#数枚のCT画像で隣接行列作成

# %matplotlib inline

import numpy as np
import cv2
from tqdm import tqdm
import matplotlib.pyplot as plt
import networkx as nx
import sys

height = 858
width  = 915
depth  = 888

v_num = 359400

diff = 15

def main():
    
    z_u = 503
    z_d = 500
    
    temp = np.zeros((z_u-z_d,height,width),dtype = 'i4')
    A = np.zeros((v_num,v_num),dtype = 'i1')
    cnt = 0
    
    print('隣接行列作成中')
    for z in tqdm(range(z_d,z_u)):
        img = cv2.imread('../../flower_CT_photo/ORA/ORA60/ORA-{0:03d}_60.png'.format(z),0)
        for y in range(height):
            for x in range(width):
                if(img[y,x]>0):
                    temp[z-z_d,y,x] = cnt
                    cnt += 1
    
    #print(temp)
    
    for z in tqdm(range(z_d,z_u)):
        img = cv2.imread('../../flower_CT_photo/ORA/ORA60/ORA-{0:03d}_60.png'.format(z),0)
        
        if(z != (z_u-1)):
            img_a = cv2.imread('../../flower_CT_photo/ORA/ORA60/ORA-{0:03d}_60.png'.format(z+1),0)
        
        for y in range(height):
            for x in range(width):
                
                if(img[y,x]>0):
                    brig1 = img[y,x]
                    node1 = temp[z-z_d,y,x]
                    
                    #print(node1)
                
                    if(x!=(width-1)):
                        
                        if(img[y,x+1]>0):
                            brig2 = img[y,x+1]
                            diff_n = abs(int(brig1)-int(brig2))
                            node2 = temp[z-z_d,y,x+1]
                            if(diff_n < diff):
                                A[node1,node2] = -1
                                A[node1,node1] += 1
                                
                                A[node2,node1] = -1
                                A[node2,node2] += 1
                                
                        
                    if(y!=(height-1)):
                    
                        if(x!=0):
                            if(img[y+1,x-1]>0):
                                brig2 = img[y+1,x-1]
                                diff_n = abs(int(brig1)-int(brig2))
                                node2 = temp[z-z_d,y+1,x-1]
                                if(diff_n < diff):
                                    A[node1,node2] = -1
                                    A[node1,node1] += 1
                                
                                    A[node2,node1] = -1
                                    A[node2,node2] += 1
                            
                        if(img[y+1,x]>0):
                            brig2 = img[y+1,x]
                            diff_n = abs(int(brig1)-int(brig2))
                            node2 = temp[z-z_d,y+1,x]
                            if(diff_n < diff):
                                A[node1,node2] = -1
                                A[node1,node1] += 1
                                
                                A[node2,node1] = -1
                                A[node2,node2] += 1

                        if(x!=(width-1)):
                            if(img[y+1,x+1]>0):
                                brig2 = img[y+1,x+1]
                                diff_n = abs(int(brig1)-int(brig2))
                                node2 = temp[z-z_d,y+1,x+1]
                                if(diff_n < diff):
                                    A[node1,node2] = -1
                                    A[node1,node1] += 1
                                
                                    A[node2,node1] = -1
                                    A[node2,node2] += 1
                                    
                    if(z!=(z_u-1)):
                        if(img_a[y,x]>0):
                            brig2 = img_a[y,x]
                            diff_n = abs(int(brig1)-int(brig2))
                            node2 = temp[z+1-z_d,y,x]
                            if(diff_n < diff):
                                A[node1,node2] = -1
                                A[node1,node1] += 1
                                
                                A[node2,node1] = -1
                                A[node2,node2] += 1
                                
                        if(x!=0):
                            if(img_a[y,x-1]>0):
                                brig2 = img_a[y,x-1]
                                diff_n = abs(int(brig1)-int(brig2))
                                node2 = temp[z+1-z_d,y,x-1]
                                if(diff_n < diff):
                                    A[node1,node2] = -1
                                    A[node1,node1] += 1
                                
                                    A[node2,node1] = -1
                                    A[node2,node2] += 1
                                    
                        if(x!=(width-1)):
                            if(img_a[y,x+1]>0):
                                brig2 = img_a[y,x+1]
                                diff_n = abs(int(brig1)-int(brig2))
                                node2 = temp[z+1-z_d,y,x+1]
                                if(diff_n < diff):
                                    A[node1,node2] = -1
                                    A[node1,node1] += 1
                                
                                    A[node2,node1] = -1
                                    A[node2,node2] += 1
                                
                        if(y!=0):
                            if(img_a[y-1,x]>0):
                                brig2 = img_a[y-1,x]
                                diff_n = abs(int(brig1)-int(brig2))
                                node2 = temp[z+1-z_d,y-1,x]
                                if(diff_n < diff):
                                    A[node1,node2] = -1
                                    A[node1,node1] += 1
                                
                                    A[node2,node1] = -1
                                    A[node2,node2] += 1
                            
                            if(x!=0):
                                if(img_a[y-1,x-1]>0):
                                    brig2 = img_a[y-1,x-1]
                                    diff_n = abs(int(brig1)-int(brig2))
                                    node2 = temp[z+1-z_d,y-1,x-1]
                                    if(diff_n < diff):
                                        A[node1,node2] = -1
                                        A[node1,node1] += 1
                                
                                        A[node2,node1] = -1
                                        A[node2,node2] += 1
                                        
                            if(x!=(width-1)):
                                if(img_a[y-1,x+1]>0):
                                    brig2 = img_a[y-1,x+1]
                                    diff_n = abs(int(brig1)-int(brig2))
                                    node2 = temp[z+1-z_d,y-1,x+1]
                                    if(diff_n < diff):
                                        A[node1,node2] = -1
                                        A[node1,node1] += 1
                                
                                        A[node2,node1] = -1
                                        A[node2,node2] += 1
                                    
                        if(y!=(height-1)):
                            if(img_a[y+1,x]>0):
                                brig2 = img_a[y+1,x]
                                diff_n = abs(int(brig1)-int(brig2))
                                node2 = temp[z+1-z_d,y+1,x]
                                if(diff_n < diff):
                                    A[node1,node2] = -1
                                    A[node1,node1] += 1
                                
                                    A[node2,node1] = -1
                                    A[node2,node2] += 1
                            
                            if(x!=0):
                                if(img_a[y+1,x-1]>0):
                                    brig2 = img_a[y+1,x-1]
                                    diff_n = abs(int(brig1)-int(brig2))
                                    node2 = temp[z+1-z_d,y+1,x-1]
                                    if(diff_n < diff):
                                        A[node1,node2] = -1
                                        A[node1,node1] += 1
                                
                                        A[node2,node1] = -1
                                        A[node2,node2] += 1
                                        
                            if(x!=(width-1)):
                                if(img_a[y+1,x+1]>0):
                                    brig2 = img_a[y+1,x+1]
                                    diff_n = abs(int(brig1)-int(brig2))
                                    node2 = temp[z+1-z_d,y+1,x+1]
                                    if(diff_n < diff):
                                        A[node1,node2] = -1
                                        A[node1,node1] += 1
                                
                                        A[node2,node1] = -1
                                        A[node2,node2] += 1
    
    
    print(A)
    
    value, vector = np.linalg.eig(A)
    
    print(value)
    print(vector)
    
    #line_sum = np.sum(A,axis=1)
    #print(line_sum)
    
    #for i in tqdm(range(v_num)):
        
                

    #plt.figure(figsize=(20,19),dpi=100)
    #fig,ax = plt.subplots(figsize=(20,19),dpi=100)
    #ax.invert_yaxis()
    
    #print('G_draw')
    #nx.draw(G,pos,node_size=10,width = edge_weight)
    #nx.draw(G,pos,node_size=50)
    
    #print('plt_draw')
    #plt.show()
    #plt.savefig("ORA-{0:03d}_{1:d}-{2:d}_{3:d}_edge.pdf".format(img_num,left,right,diff))
    #plt.savefig("ORA-{0:03d}_{1:d}.pdf".format(img_num,diff))

if __name__ == "__main__":
    main()

# %%
#CT画像1枚でスペクトラルクラスタリング

# %matplotlib inline

import numpy as np
import cv2
from tqdm import tqdm
import matplotlib.pyplot as plt
import networkx as nx
import sys
import numpy.linalg as LA
import datetime

#height = 858
#width  = 915
#depth  = 888

#v_num = 0

diff = 15

def main():
    
    z = 500
    img = cv2.imread('Input/ORA-479_230-293.png',0)
    
    height, width = img.shape
    
    temp = np.zeros((height,width),dtype = 'i4')
    cnt = 0
    
    now = datetime.datetime.now()
    print(now)
    print('ノード番号付与中')
    
    #img = cv2.imread('../../flower_CT_photo/ORA/ORA60/ORA-{0:03d}_60.png'.format(z),0)
    
    for y in range(height):
        for x in range(width):
            if(img[y,x]>60):
                temp[y,x] = cnt
                cnt += 1
                
    print(cnt+1)
                    
    #A = np.zeros((cnt+1,cnt+1),dtype = 'f2')
    A = np.zeros((cnt+1,cnt+1))
    
    #print(temp)
    
    #img = cv2.imread('../../flower_CT_photo/ORA/ORA60/ORA-{0:03d}_60.png'.format(z),0)
    
    now = datetime.datetime.now()
    print(now)
    print('隣接行列作成中')
    
    for y in tqdm(range(height)):
        for x in range(width):
                
            if(img[y,x]>60):
                brig1 = img[y,x]
                node1 = temp[y,x]
                
                if(x!=(width-1)):
                        
                    if(img[y,x+1]>0):
                        brig2 = img[y,x+1]
                        diff_n = abs(int(brig1)-int(brig2))
                        node2 = temp[y,x+1]
                        if(diff_n < diff):
                            A[node1,node2] = -1
                            A[node1,node1] += 1
                                
                            A[node2,node1] = -1
                            A[node2,node2] += 1
                                
                        
                if(y!=(height-1)):
                    
                    if(x!=0):
                        if(img[y+1,x-1]>0):
                            brig2 = img[y+1,x-1]
                            diff_n = abs(int(brig1)-int(brig2))
                            node2 = temp[y+1,x-1]
                            if(diff_n < diff):
                                A[node1,node2] = -1
                                A[node1,node1] += 1
                                
                                A[node2,node1] = -1
                                A[node2,node2] += 1
                            
                    if(img[y+1,x]>0):
                        brig2 = img[y+1,x]
                        diff_n = abs(int(brig1)-int(brig2))
                        node2 = temp[y+1,x]
                        if(diff_n < diff):
                            A[node1,node2] = -1
                            A[node1,node1] += 1
                                
                            A[node2,node1] = -1
                            A[node2,node2] += 1

                    if(x!=(width-1)):
                        if(img[y+1,x+1]>0):
                            brig2 = img[y+1,x+1]
                            diff_n = abs(int(brig1)-int(brig2))
                            node2 = temp[y+1,x+1]
                            if(diff_n < diff):
                                A[node1,node2] = -1
                                A[node1,node1] += 1
                                
                                A[node2,node1] = -1
                                A[node2,node2] += 1

    now = datetime.datetime.now()
    print(now)
    print("固有値計算開始")
    value, vector = LA.eig(A)
    
    now = datetime.datetime.now()
    print(now)
    print("固有値")
    print(value)
    print(vector)
    
    img_col = cv2.imread('Input/ORA-479_230-293.png')
    
    
    plt.figure(figsize=(20,19),dpi=100)
    fig,ax = plt.subplots(figsize=(20,19),dpi=100)
    
    x = np.linspace(0, cnt,cnt+1)
    y = vector[4,:]
    
    plt.plot(x, y, marker=".", color = "red", linestyle = "-")
    plt.savefig("ORA-test_4.pdf")
    

if __name__ == "__main__":
    main()

# %%
 #一時保管   
    
    img_col = cv2.imread('Input/ORA-479_230-293.png')
    
    for i in tqdm(range(cnt+1)):
        y,x = np.where(temp == i)
        
        if(0 <= vector[3,i] < 0.01):
            img_col[y,x] = (0,0,100)
        elif(0.01 <= vector[3,i] < 0.02):
            img_col[y,x] = (0,0,200)
        elif(0.02 <= vector[3,i]):
            img_col[y,x] = (0,0,255)
        elif(-0.01 < vector[3,i] < 0):
            img_col[y,x] = (100,0,0)
        elif(-0.02 < vector[3,i] <= -0.01):
            img_col[y,x] = (200,0,0)
        elif(vector[3,i] < -0.02):
            img_col[y,x] = (255,0,0)
    
    cv2.imwrite('ORA-{0:03d}_color.png'.format(z),img_col)
    
    
    
    plt.figure(figsize=(20,19),dpi=100)
    fig,ax = plt.subplots(figsize=(20,19),dpi=100)
    
    x = np.linspace(0, cnt,cnt+1)
    y = vector[3,:]
    
    plt.plot(x, y, marker=".", color = "red", linestyle = "-")
    plt.savefig("ORA-test.pdf")
    
    for y in range(height):
        for x in range(width):
            if(img[y,x]>60):
                i = temp[y,x]
        
                if(0 < vector[3,i]):
                    img_col[y,x] = (0,0,255)
                elif(vector[3,i] == 0):
                    img_col[y,x] = (0,255,0)
                elif(vector[3,i] < 0):
                    img_col[y,x] = (255,0,0)
    
    cv2.imwrite('ORA-{0:03d}_color_2.png'.format(z),img_col)

# %%
#全ボクセルの隣接行列を表現　スパース行列使用
# %matplotlib inline

import numpy as np
import cv2
from tqdm import tqdm
import matplotlib.pyplot as plt
import networkx as nx
import sys
from scipy.sparse import lil_matrix
import numpy.linalg as LA
import datetime
from scipy.sparse import csr_matrix, csc_matrix
from scipy.sparse.linalg import inv, eigs

#height = 858
#width  = 915
depth  = 888

diff = 15

def main():
    
    img = cv2.imread('../../flower_CT_photo/ORA/ORA60/ORA-000_60.png',0)
    height,width = img.shape
    
    temp = np.zeros((depth,height,width),dtype = 'i4')
    #A = np.zeros((73904285,73904285),dtype = 'i4')
    cnt = 0
    
    now = datetime.datetime.now()
    print(now)
    
    print('ノード番号付与中')
    for z in tqdm(range(depth)):
        img = cv2.imread('../../flower_CT_photo/ORA/ORA60/ORA-{0:03d}_60.png'.format(z),0)
        for y in range(height):
            for x in range(width):
                if(img[y,x]>0):
                    temp[z,y,x] = cnt
                    cnt += 1
                    
    now = datetime.datetime.now()
    print(now)

    print('スパース行列作成')
    A = lil_matrix((cnt+1,cnt+1),dtype='float')
    
    now = datetime.datetime.now()
    print(now)
    
    print('隣接行列作成中')
    
    for z in tqdm(range(depth)):
        img = cv2.imread('../../flower_CT_photo/ORA/ORA60/ORA-{0:03d}_60.png'.format(z),0)
        
        if(z != (depth-1)):
            img_a = cv2.imread('../../flower_CT_photo/ORA/ORA60/ORA-{0:03d}_60.png'.format(z),0)
        
        for y in range(height):
            for x in range(width):
                
                node1 = temp[z,y,x]
                
                if(img[y,x]>0):
                    brig1 = img[y,x]
                
                    if(x!=(width-1)):
                        
                        if(img[y,x+1]>0):
                            brig2 = img[y,x+1]
                            diff_n = abs(int(brig1)-int(brig2))
                            node2 = temp[z,y,x+1]
                            if(diff_n < diff):
                                A[node1,node2] = -1
                                A[node1,node1] += 1
                                
                                A[node2,node1] = -1
                                A[node2,node2] += 1
                        
                    if(y!=(height-1)):
                    
                        if(x!=0):
                            if(img[y+1,x-1]>0):
                                brig2 = img[y+1,x-1]
                                diff_n = abs(int(brig1)-int(brig2))
                                node2 = temp[z,y+1,x-1]
                                if(diff_n < diff):
                                    A[node1,node2] = -1
                                    A[node1,node1] += 1
                                
                                    A[node2,node1] = -1
                                    A[node2,node2] += 1
                            
                        if(img[y+1,x]>0):
                            brig2 = img[y+1,x]
                            diff_n = abs(int(brig1)-int(brig2))
                            node2 = temp[z,y+1,x]
                            if(diff_n < diff):
                                A[node1,node2] = -1
                                A[node1,node1] += 1
                                
                                A[node2,node1] = -1
                                A[node2,node2] += 1

                        if(x!=(width-1)):
                            if(img[y+1,x+1]>0):
                                brig2 = img[y+1,x+1]
                                diff_n = abs(int(brig1)-int(brig2))
                                node2 = temp[z,y+1,x+1]
                                if(diff_n < diff):
                                    A[node1,node2] = -1
                                    A[node1,node1] += 1
                                
                                    A[node2,node1] = -1
                                    A[node2,node2] += 1
                                    
                    if(z!=(depth-1)):
                        if(img_a[y,x]>0):
                            brig2 = img_a[y,x]
                            diff_n = abs(int(brig1)-int(brig2))
                            node2 = temp[z+1,y,x]
                            if(diff_n < diff):
                                A[node1,node2] = -1
                                A[node1,node1] += 1
                                
                                A[node2,node1] = -1
                                A[node2,node2] += 1
                                
                        if(x!=0):
                            if(img_a[y,x-1]>0):
                                brig2 = img_a[y,x-1]
                                diff_n = abs(int(brig1)-int(brig2))
                                node2 = temp[z+1,y,x-1]
                                if(diff_n < diff):
                                    A[node1,node2] = -1
                                    A[node1,node1] += 1
                                
                                    A[node2,node1] = -1
                                    A[node2,node2] += 1
                                    
                        if(x!=(width-1)):
                            if(img_a[y,x+1]>0):
                                brig2 = img_a[y,x+1]
                                diff_n = abs(int(brig1)-int(brig2))
                                node2 = temp[z+1,y,x+1]
                                if(diff_n < diff):
                                    A[node1,node2] = -1
                                    A[node1,node1] += 1
                                
                                    A[node2,node1] = -1
                                    A[node2,node2] += 1
                                
                        if(y!=0):
                            if(img_a[y-1,x]>0):
                                brig2 = img_a[y-1,x-1]
                                diff_n = abs(int(brig1)-int(brig2))
                                node2 = temp[z+1,y-1,x-1]
                                if(diff_n < diff):
                                    A[node1,node2] = -1
                                    A[node1,node1] += 1
                                
                                    A[node2,node1] = -1
                                    A[node2,node2] += 1
                            
                            if(x!=0):
                                if(img_a[y-1,x-1]>0):
                                    brig2 = img_a[y-1,x]
                                    diff_n = abs(int(brig1)-int(brig2))
                                    node2 = temp[z+1,y-1,x]
                                    if(diff_n < diff):
                                        A[node1,node2] = -1
                                        A[node1,node1] += 1
                                
                                        A[node2,node1] = -1
                                        A[node2,node2] += 1
                                        
                            if(x!=(width-1)):
                                if(img_a[y-1,x+1]>0):
                                    brig2 = img_a[y-1,x]
                                    diff_n = abs(int(brig1)-int(brig2))
                                    node2 = temp[z+1,y-1,x]
                                    if(diff_n < diff):
                                        A[node1,node2] = -1
                                        A[node1,node1] += 1
                                
                                        A[node2,node1] = -1
                                        A[node2,node2] += 1
                                    
                        if(y!=(height-1)):
                            if(img_a[y+1,x]>0):
                                brig2 = img_a[y+1,x-1]
                                diff_n = abs(int(brig1)-int(brig2))
                                node2 = temp[z+1,y+1,x-1]
                                if(diff_n < diff):
                                    A[node1,node2] = -1
                                    A[node1,node1] += 1
                                
                                    A[node2,node1] = -1
                                    A[node2,node2] += 1
                            
                            if(x!=0):
                                if(img_a[y+1,x-1]>0):
                                    brig2 = img_a[y+1,x-1]
                                    diff_n = abs(int(brig1)-int(brig2))
                                    node2 = temp[z+1,y+1,x-1]
                                    if(diff_n < diff):
                                        A[node1,node2] = -1
                                        A[node1,node1] += 1
                                
                                        A[node2,node1] = -1
                                        A[node2,node2] += 1
                                        
                            if(x!=(width-1)):
                                if(img_a[y+1,x+1]>0):
                                    brig2 = img_a[y+1,x+1]
                                    diff_n = abs(int(brig1)-int(brig2))
                                    node2 = temp[z+1,y+1,x+1]
                                    if(diff_n < diff):
                                        A[node1,node2] = -1
                                        A[node1,node1] += 1
                                
                                        A[node2,node1] = -1
                                        A[node2,node2] += 1
    
    A = csr_matrix(A)
    
    now = datetime.datetime.now()
    print(now)
    
    print('固有値計算')
    w, v = eigs(A, k=2)
    
    print(w)
    print(v)
    
    
    #plt.figure(figsize=(20,19),dpi=100)
    #fig,ax = plt.subplots(figsize=(20,19),dpi=100)
    #ax.invert_yaxis()
    
    #print('G_draw')
    #nx.draw(G,pos,node_size=10,width = edge_weight)
    #nx.draw(G,pos,node_size=50)
    
    #print('plt_draw')
    #plt.show()
    #plt.savefig("ORA-{0:03d}_{1:d}-{2:d}_{3:d}_edge.pdf".format(img_num,left,right,diff))
    #plt.savefig("ORA-{0:03d}_{1:d}.pdf".format(img_num,diff))

if __name__ == "__main__":
    main()

# %% [markdown]
# 数枚のCT画像で隣接行列作成　スパース行列使用

# %%
# %matplotlib inline

import numpy as np
import cv2
from tqdm import tqdm
import matplotlib.pyplot as plt
import networkx as nx
import sys
from scipy.sparse import lil_matrix
import numpy.linalg as LA
import datetime
from scipy.sparse import csr_matrix, csc_matrix
from scipy.sparse.linalg import inv, eigs

height = 858
width  = 915
depth  = 888

#v_num = 359400

diff = 15

def main():
    
    z_u = 503
    z_d = 500
    
    temp = np.zeros((z_u-z_d,height,width),dtype = 'i4')
    
    cnt = 0
    
    now = datetime.datetime.now()
    print(now)
    
    print('ノード番号付与中')
    for z in tqdm(range(z_d,z_u)):
        img = cv2.imread('../../flower_CT_photo/ORA/ORA60/ORA-{0:03d}_60.png'.format(z),0)
        for y in range(height):
            for x in range(width):
                if(img[y,x]>0):
                    temp[z-z_d,y,x] = cnt
                    cnt += 1
    
    now = datetime.datetime.now()
    print(now)

    print('スパース行列作成')
    A = lil_matrix((cnt+1,cnt+1),dtype='float')
    
    now = datetime.datetime.now()
    print(now)
    
    print('隣接行列作成中')
    
    for z in tqdm(range(z_d,z_u)):
        img = cv2.imread('../../flower_CT_photo/ORA/ORA60/ORA-{0:03d}_60.png'.format(z),0)
        
        if(z != (z_u-1)):
            img_a = cv2.imread('../../flower_CT_photo/ORA/ORA60/ORA-{0:03d}_60.png'.format(z+1),0)
        
        for y in range(height):
            for x in range(width):
                
                if(img[y,x]>0):
                    brig1 = img[y,x]
                    node1 = temp[z-z_d,y,x]
                    
                    #print(node1)
                
                    if(x!=(width-1)):
                        
                        if(img[y,x+1]>0):
                            brig2 = img[y,x+1]
                            diff_n = abs(int(brig1)-int(brig2))
                            node2 = temp[z-z_d,y,x+1]
                            if(diff_n < diff):
                                A[node1,node2] = -1
                                A[node1,node1] += 1
                                
                                A[node2,node1] = -1
                                A[node2,node2] += 1
                                
                        
                    if(y!=(height-1)):
                    
                        if(x!=0):
                            if(img[y+1,x-1]>0):
                                brig2 = img[y+1,x-1]
                                diff_n = abs(int(brig1)-int(brig2))
                                node2 = temp[z-z_d,y+1,x-1]
                                if(diff_n < diff):
                                    A[node1,node2] = -1
                                    A[node1,node1] += 1
                                
                                    A[node2,node1] = -1
                                    A[node2,node2] += 1
                            
                        if(img[y+1,x]>0):
                            brig2 = img[y+1,x]
                            diff_n = abs(int(brig1)-int(brig2))
                            node2 = temp[z-z_d,y+1,x]
                            if(diff_n < diff):
                                A[node1,node2] = -1
                                A[node1,node1] += 1
                                
                                A[node2,node1] = -1
                                A[node2,node2] += 1

                        if(x!=(width-1)):
                            if(img[y+1,x+1]>0):
                                brig2 = img[y+1,x+1]
                                diff_n = abs(int(brig1)-int(brig2))
                                node2 = temp[z-z_d,y+1,x+1]
                                if(diff_n < diff):
                                    A[node1,node2] = -1
                                    A[node1,node1] += 1
                                
                                    A[node2,node1] = -1
                                    A[node2,node2] += 1
                                    
                    if(z!=(z_u-1)):
                        if(img_a[y,x]>0):
                            brig2 = img_a[y,x]
                            diff_n = abs(int(brig1)-int(brig2))
                            node2 = temp[z+1-z_d,y,x]
                            if(diff_n < diff):
                                A[node1,node2] = -1
                                A[node1,node1] += 1
                                
                                A[node2,node1] = -1
                                A[node2,node2] += 1
                                
                        if(x!=0):
                            if(img_a[y,x-1]>0):
                                brig2 = img_a[y,x-1]
                                diff_n = abs(int(brig1)-int(brig2))
                                node2 = temp[z+1-z_d,y,x-1]
                                if(diff_n < diff):
                                    A[node1,node2] = -1
                                    A[node1,node1] += 1
                                
                                    A[node2,node1] = -1
                                    A[node2,node2] += 1
                                    
                        if(x!=(width-1)):
                            if(img_a[y,x+1]>0):
                                brig2 = img_a[y,x+1]
                                diff_n = abs(int(brig1)-int(brig2))
                                node2 = temp[z+1-z_d,y,x+1]
                                if(diff_n < diff):
                                    A[node1,node2] = -1
                                    A[node1,node1] += 1
                                
                                    A[node2,node1] = -1
                                    A[node2,node2] += 1
                                
                        if(y!=0):
                            if(img_a[y-1,x]>0):
                                brig2 = img_a[y-1,x]
                                diff_n = abs(int(brig1)-int(brig2))
                                node2 = temp[z+1-z_d,y-1,x]
                                if(diff_n < diff):
                                    A[node1,node2] = -1
                                    A[node1,node1] += 1
                                
                                    A[node2,node1] = -1
                                    A[node2,node2] += 1
                            
                            if(x!=0):
                                if(img_a[y-1,x-1]>0):
                                    brig2 = img_a[y-1,x-1]
                                    diff_n = abs(int(brig1)-int(brig2))
                                    node2 = temp[z+1-z_d,y-1,x-1]
                                    if(diff_n < diff):
                                        A[node1,node2] = -1
                                        A[node1,node1] += 1
                                
                                        A[node2,node1] = -1
                                        A[node2,node2] += 1
                                        
                            if(x!=(width-1)):
                                if(img_a[y-1,x+1]>0):
                                    brig2 = img_a[y-1,x+1]
                                    diff_n = abs(int(brig1)-int(brig2))
                                    node2 = temp[z+1-z_d,y-1,x+1]
                                    if(diff_n < diff):
                                        A[node1,node2] = -1
                                        A[node1,node1] += 1
                                
                                        A[node2,node1] = -1
                                        A[node2,node2] += 1
                                    
                        if(y!=(height-1)):
                            if(img_a[y+1,x]>0):
                                brig2 = img_a[y+1,x]
                                diff_n = abs(int(brig1)-int(brig2))
                                node2 = temp[z+1-z_d,y+1,x]
                                if(diff_n < diff):
                                    A[node1,node2] = -1
                                    A[node1,node1] += 1
                                
                                    A[node2,node1] = -1
                                    A[node2,node2] += 1
                            
                            if(x!=0):
                                if(img_a[y+1,x-1]>0):
                                    brig2 = img_a[y+1,x-1]
                                    diff_n = abs(int(brig1)-int(brig2))
                                    node2 = temp[z+1-z_d,y+1,x-1]
                                    if(diff_n < diff):
                                        A[node1,node2] = -1
                                        A[node1,node1] += 1
                                
                                        A[node2,node1] = -1
                                        A[node2,node2] += 1
                                        
                            if(x!=(width-1)):
                                if(img_a[y+1,x+1]>0):
                                    brig2 = img_a[y+1,x+1]
                                    diff_n = abs(int(brig1)-int(brig2))
                                    node2 = temp[z+1-z_d,y+1,x+1]
                                    if(diff_n < diff):
                                        A[node1,node2] = -1
                                        A[node1,node1] += 1
                                
                                        A[node2,node1] = -1
                                        A[node2,node2] += 1
    
    
    A = csr_matrix(A)
    
    now = datetime.datetime.now()
    print(now)
    
    print('固有値計算')
    w, v = eigs(A, k=2)
    
    #plt.figure(figsize=(20,19),dpi=100)
    fig,ax = plt.subplots(figsize=(30,30),dpi=100)
    
    print(v.shape)
    
    x = np.linspace(0, cnt,cnt+1)
    y = v[:,1]
    
    plt.plot(x, y, marker=".", color = "red", linestyle = "-")
    plt.savefig("ORA-test_500-502.pdf")

if __name__ == "__main__":
    main()

# %%
# %matplotlib inline

import numpy as np
import cv2
from tqdm import tqdm
import matplotlib.pyplot as plt
import networkx as nx
import sys
from scipy.sparse import lil_matrix
import numpy.linalg as LA
import datetime
from scipy.sparse import csr_matrix, csc_matrix
from scipy.sparse.linalg import inv, eigs

height = 858
width  = 915
depth  = 888

#v_num = 359400

diff = 15

z_u = 666
z_d = 663
    
temp = np.zeros((z_u-z_d,height,width),dtype = 'i4')
    
cnt = 0
cnt_0 = 0
cnt_1 = 0
cnt_2 = 0

now = datetime.datetime.now()
print(now)
    
print('ノード番号付与中')
for z in tqdm(range(z_d,z_u)):
    img = cv2.imread('../../flower_CT_photo/ORA/ORA60/ORA-{0:03d}_60.png'.format(z),0)
    for y in range(height):
        for x in range(width):
            if(img[y,x]>0):
                temp[z-z_d,y,x] = cnt
                cnt += 1
                if(z==z_d):
                    cnt_0 += 1
                elif(z==z_d+1):
                    cnt_1 += 1
                elif(z==z_d+2):
                    cnt_2 += 1

now = datetime.datetime.now()
print(now)

print('スパース行列作成')
A = lil_matrix((cnt+1,cnt+1),dtype='float')

now = datetime.datetime.now()
print(now)

print('隣接行列作成中')

for z in tqdm(range(z_d,z_u)):
    img = cv2.imread('../../flower_CT_photo/ORA/ORA60/ORA-{0:03d}_60.png'.format(z),0)

    if(z != (z_u-1)):
        img_a = cv2.imread('../../flower_CT_photo/ORA/ORA60/ORA-{0:03d}_60.png'.format(z+1),0)

    for y in range(height):
        for x in range(width):

            if(img[y,x]>0):
                brig1 = img[y,x]
                node1 = temp[z-z_d,y,x]

                #print(node1)

                if(x!=(width-1)):

                    if(img[y,x+1]>0):
                        brig2 = img[y,x+1]
                        diff_n = abs(int(brig1)-int(brig2))
                        node2 = temp[z-z_d,y,x+1]
                        if(diff_n < diff):
                            A[node1,node2] = -1
                            A[node1,node1] += 1

                            A[node2,node1] = -1
                            A[node2,node2] += 1


                if(y!=(height-1)):

                    if(x!=0):
                        if(img[y+1,x-1]>0):
                            brig2 = img[y+1,x-1]
                            diff_n = abs(int(brig1)-int(brig2))
                            node2 = temp[z-z_d,y+1,x-1]
                            if(diff_n < diff):
                                A[node1,node2] = -1
                                A[node1,node1] += 1

                                A[node2,node1] = -1
                                A[node2,node2] += 1

                    if(img[y+1,x]>0):
                        brig2 = img[y+1,x]
                        diff_n = abs(int(brig1)-int(brig2))
                        node2 = temp[z-z_d,y+1,x]
                        if(diff_n < diff):
                            A[node1,node2] = -1
                            A[node1,node1] += 1

                            A[node2,node1] = -1
                            A[node2,node2] += 1

                    if(x!=(width-1)):
                        if(img[y+1,x+1]>0):
                            brig2 = img[y+1,x+1]
                            diff_n = abs(int(brig1)-int(brig2))
                            node2 = temp[z-z_d,y+1,x+1]
                            if(diff_n < diff):
                                A[node1,node2] = -1
                                A[node1,node1] += 1

                                A[node2,node1] = -1
                                A[node2,node2] += 1

                if(z!=(z_u-1)):
                    if(img_a[y,x]>0):
                        brig2 = img_a[y,x]
                        diff_n = abs(int(brig1)-int(brig2))
                        node2 = temp[z+1-z_d,y,x]
                        if(diff_n < diff):
                            A[node1,node2] = -1
                            A[node1,node1] += 1

                            A[node2,node1] = -1
                            A[node2,node2] += 1

                    if(x!=0):
                        if(img_a[y,x-1]>0):
                            brig2 = img_a[y,x-1]
                            diff_n = abs(int(brig1)-int(brig2))
                            node2 = temp[z+1-z_d,y,x-1]
                            if(diff_n < diff):
                                A[node1,node2] = -1
                                A[node1,node1] += 1

                                A[node2,node1] = -1
                                A[node2,node2] += 1

                    if(x!=(width-1)):
                        if(img_a[y,x+1]>0):
                            brig2 = img_a[y,x+1]
                            diff_n = abs(int(brig1)-int(brig2))
                            node2 = temp[z+1-z_d,y,x+1]
                            if(diff_n < diff):
                                A[node1,node2] = -1
                                A[node1,node1] += 1

                                A[node2,node1] = -1
                                A[node2,node2] += 1

                    if(y!=0):
                        if(img_a[y-1,x]>0):
                            brig2 = img_a[y-1,x]
                            diff_n = abs(int(brig1)-int(brig2))
                            node2 = temp[z+1-z_d,y-1,x]
                            if(diff_n < diff):
                                A[node1,node2] = -1
                                A[node1,node1] += 1

                                A[node2,node1] = -1
                                A[node2,node2] += 1

                        if(x!=0):
                            if(img_a[y-1,x-1]>0):
                                brig2 = img_a[y-1,x-1]
                                diff_n = abs(int(brig1)-int(brig2))
                                node2 = temp[z+1-z_d,y-1,x-1]
                                if(diff_n < diff):
                                    A[node1,node2] = -1
                                    A[node1,node1] += 1

                                    A[node2,node1] = -1
                                    A[node2,node2] += 1

                        if(x!=(width-1)):
                            if(img_a[y-1,x+1]>0):
                                brig2 = img_a[y-1,x+1]
                                diff_n = abs(int(brig1)-int(brig2))
                                node2 = temp[z+1-z_d,y-1,x+1]
                                if(diff_n < diff):
                                    A[node1,node2] = -1
                                    A[node1,node1] += 1

                                    A[node2,node1] = -1
                                    A[node2,node2] += 1

                    if(y!=(height-1)):
                        if(img_a[y+1,x]>0):
                            brig2 = img_a[y+1,x]
                            diff_n = abs(int(brig1)-int(brig2))
                            node2 = temp[z+1-z_d,y+1,x]
                            if(diff_n < diff):
                                A[node1,node2] = -1
                                A[node1,node1] += 1

                                A[node2,node1] = -1
                                A[node2,node2] += 1

                        if(x!=0):
                            if(img_a[y+1,x-1]>0):
                                brig2 = img_a[y+1,x-1]
                                diff_n = abs(int(brig1)-int(brig2))
                                node2 = temp[z+1-z_d,y+1,x-1]
                                if(diff_n < diff):
                                    A[node1,node2] = -1
                                    A[node1,node1] += 1

                                    A[node2,node1] = -1
                                    A[node2,node2] += 1

                        if(x!=(width-1)):
                            if(img_a[y+1,x+1]>0):
                                brig2 = img_a[y+1,x+1]
                                diff_n = abs(int(brig1)-int(brig2))
                                node2 = temp[z+1-z_d,y+1,x+1]
                                if(diff_n < diff):
                                    A[node1,node2] = -1
                                    A[node1,node1] += 1

                                    A[node2,node1] = -1
                                    A[node2,node2] += 1

# %%
A = csr_matrix(A)
    
now = datetime.datetime.now()
print(now)

print('固有値計算')
w, v = eigs(A, k=27)

# %%
now = datetime.datetime.now()
print(now)

print('固有ベクトル値表示')

#plt.figure(figsize=(20,19),dpi=100)
fig,ax = plt.subplots(figsize=(30,30),dpi=100)

print(v.shape)

x = np.linspace(0, cnt_1-1,cnt_1)
y = v[cnt_0:cnt_0+cnt_1,1]

#y.sort()

plt.plot(x, y, marker=".", color = "red", linestyle = "-")
plt.savefig("ORA-test_{0:03d}-{1:03d}_{2:d}_.pdf".format(z_d,z_u-1,diff))

# %%
img_col = cv2.imread('../../flower_CT_photo/ORA/ORA60/ORA-{0:03d}_60.png'.format(z_d+1))
    
for i in tqdm(range(cnt_0,cnt_0+cnt_1-1)):
#for i in tqdm(range(cnt_0+21428,cnt_0+25000)):
    z,y,x = np.where(temp == i)
    
    #img_col[y,x] = (0,0,255)

    if(0.00000001 <= v[i,1]):
        img_col[y,x] = (0,0,255)
    elif(v[i,1] < -0.00000001):
        img_col[y,x] = (255,0,0)

cv2.imwrite('ORA-{0:03d}_color_test_1.png'.format(z_d+1),img_col)

# %% [markdown]
# 一部のみ

# %%
from PIL import Image

im = Image.open('../../flower_CT_photo/ORA/[vg-data] ORA/volume_1/ORA-663.tif')

im.crop((254,285,284,313)).save('Input/ORA-663_254-284.png')

# %%
# %matplotlib inline

import numpy as np
import cv2
from tqdm import tqdm
import matplotlib.pyplot as plt
import networkx as nx
import sys
from scipy.sparse import lil_matrix
import numpy.linalg as LA
import datetime
from scipy.sparse import csr_matrix, csc_matrix
from scipy.sparse.linalg import inv, eigs

diff = 255

th = 60
    
cnt = 1

now = datetime.datetime.now()
print(now)
    
print('ノード番号付与中')

img = cv2.imread('Input/ORA-663_254-284.png',0)
#img = cv2.imread('Input/test.png',0)

height,width = img.shape

temp = np.zeros((height,width),dtype = 'i4')

for y in range(height):
    for x in range(width):
        if(img[y,x]>th):
            temp[y,x] = cnt
            cnt += 1

now = datetime.datetime.now()
print(now)

print('スパース行列作成')
#A = lil_matrix((cnt+1,cnt+1),dtype='float')
A = np.zeros((cnt,cnt),dtype='float')

now = datetime.datetime.now()
print(now)

print('隣接行列作成中')

for y in tqdm(range(height)):
    for x in range(width):

        if(img[y,x]>th):
            brig1 = img[y,x]
            node1 = temp[y,x]-1

            #print(node1)

            if(x!=(width-1)):

                if(img[y,x+1]>th):
                    brig2 = img[y,x+1]
                    diff_n = abs(int(brig1)-int(brig2))
                    node2 = temp[y,x+1]-1
                    if(diff_n < diff):
                        A[node1,node2] = -1
                        A[node1,node1] += 1

                        A[node2,node1] = -1
                        A[node2,node2] += 1


            if(y!=(height-1)):
                
                if(img[y+1,x]>th):
                    brig2 = img[y+1,x]
                    diff_n = abs(int(brig1)-int(brig2))
                    node2 = temp[y+1,x]-1
                    if(diff_n < diff):
                        A[node1,node2] = -1
                        A[node1,node1] += 1

                        A[node2,node1] = -1
                        A[node2,node2] += 1

                if(x!=0):
                    if(img[y+1,x-1]>th):
                        brig2 = img[y+1,x-1]
                        diff_n = abs(int(brig1)-int(brig2))
                        node2 = temp[y+1,x-1]-1
                        if(diff_n < diff):
                            A[node1,node2] = -1
                            A[node1,node1] += 1

                            A[node2,node1] = -1
                            A[node2,node2] += 1

                if(x!=(width-1)):
                    if(img[y+1,x+1]>th):
                        brig2 = img[y+1,x+1]
                        diff_n = abs(int(brig1)-int(brig2))
                        node2 = temp[y+1,x+1]-1
                        if(diff_n < diff):
                            A[node1,node2] = -1
                            A[node1,node1] += 1

                            A[node2,node1] = -1
                            A[node2,node2] += 1

# %%
w,v = LA.eig(A)

now = datetime.datetime.now()
print(now)

# %%
now = datetime.datetime.now()
print(now)

print('固有ベクトル値表示')

#plt.figure(figsize=(20,19),dpi=100)
fig,ax = plt.subplots(figsize=(30,30),dpi=100)

print(v.shape)

x = np.linspace(0, cnt, cnt)
y = v[1,:]
y_n = sorted(y)

#y.sort()

plt.plot(x, y, marker=".", color = "red", linestyle = "-")
plt.savefig("ORA-test_663_{0:d}_254-284.pdf".format(diff))
#plt.savefig("test.pdf")

# %%
#img_col = cv2.imread('Input/ORA-663_338-387.png')
img_col = cv2.imread('Input/test.png')
    
for y in tqdm(range(height)):
    for x in range(width):
#for i in tqdm(range(cnt_0+21428,cnt_0+25000)):
        if(temp[y,x]>0):
            #y,x = np.where(temp == i)
            
            #img_col[y,x] = (0,0,255)

            i = temp[y,x]-1
            
            #if(0.1 < v[i,1]):
                #img_col[y,x] = (0,0,255)
            if(v[i,1]==0):
                img_col[y,x] = (0,255,0)
            else:
                img_col[y,x] = (0,0,255)

#cv2.imwrite('ORA-663_color_test_1_338-387.png',img_col)
cv2.imwrite('test_out.png',img_col)
